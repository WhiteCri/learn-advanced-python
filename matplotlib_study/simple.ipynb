# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
import math
x = np.arange(0, math.pi*2, 0.05)
y = np.sin(x)

# %%
plt.xlabel("angle")
plt.ylabel("sine")
plt.title('sine wave')
# Out:
# Text(0.5, 1.0, 'sine wave')

# %%
plt.plot(x,y)
